# %%
import sys

sys.path.append("../")

import pandas as pd
import numpy as np
import datetime
import os
from pprint import pprint
import matplotlib.pyplot as plt
import time
import vectorbtpro as vbt
from time import time
import helpers as pth
import platform
from dotenv import load_dotenv
import scipy.stats as stats
import time

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 20)

plt.style.use("classic")
# plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["axes.formatter.limits"] = [-1000000000, 1000000000]


if platform.system().lower() == "windows":
    base_data_path = "H:\\phitech-data\\01_raw"
else:
    from core_chains.simple.llm import make_Q_chain

    base_data_path = "../../phitech-data/01_raw"
    load_dotenv("../../sandatasci-core/credentials")
    Q = make_Q_chain("gpt-4o-instance1", __vsc_ipynb_file__)
# Out:
# /Users/e1211913/miniconda3/envs/trading/lib/python3.12/site-packages/telegram/utils/request.py:49: UserWarning: python-telegram-bot is using upstream urllib3. This is allowed but not supported by python-telegram-bot maintainers.
#   warnings.warn(
# logging mode: dev

# %%
# %%html
# <style>
# .dataframe {
#     font-size: 9pt; /* Adjust font size as needed */
# }
# </style>
# Out:
# <style>
# .dataframe {
#     font-size: 9pt; /* Adjust font size as needed */
# }
# </style>

# %%
df = pth.load_instruments(base_path=base_data_path)
df.keys()
# Out:
# dict_keys(['6B', 'MES'])

# %%
df["6B"].close
# Out:
# timestamp
# 2024-5-19  23:00:00.000000    1.2706
# 2024-5-19  23:01:00.000000    1.2707
# 2024-5-19  23:02:00.000000    1.2707
# 2024-5-19  23:03:00.000000    1.2708
# 2024-5-19  23:04:00.000000    1.2708
#                                ...
# 2025-3-14  18:07:00.000000    1.2928
# 2025-3-14  18:08:00.000000    1.2928
# 2025-3-14  18:09:00.000000    1.2927
# 2025-3-14  18:11:00.000000    1.2929
# 2025-3-14  18:12:00.000000    1.2929
# Name: close, Length: 268474, dtype: float64

# %%
# TODO: continue here when you figure out how to use data
# df.vbt.plot()

# %%
df.data['ADAUSDT'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2773 entries, 2017-08-17 00:00:00+00:00 to 2025-03-20 00:00:00+00:00
# Freq: D
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Open                2530 non-null   float64
#  1   High                2530 non-null   float64
#  2   Low                 2530 non-null   float64
#  3   Close               2530 non-null   float64
#  4   Volume              2530 non-null   float64
#  5   Quote volume        2530 non-null   float64
#  6   Trade count         2530 non-null   float64
#  7   Taker base volume   2530 non-null   float64
#  8   Taker quote volume  2530 non-null   float64
# dtypes: float64(9)
# memory usage: 216.6 KB

# %%
vbt.indicator("talib:RSI") # fast indicator, but no plotting
# Out:
# vectorbtpro.indicators.factory.talib.RSI

# %%
# tiny bit slower + plotting
vbt.RSI
# Out:
# vectorbtpro.indicators.custom.rsi.RSI

# %%
rsi = vbt.RSI.run(df.get('Close', 'ADAUSDT'))
rsi.rsi
# Out:
# Open time
# 2017-08-17 00:00:00+00:00          NaN
# 2017-08-18 00:00:00+00:00          NaN
# 2017-08-19 00:00:00+00:00          NaN
# 2017-08-20 00:00:00+00:00          NaN
# 2017-08-21 00:00:00+00:00          NaN
#                                ...
# 2025-03-16 00:00:00+00:00    45.195270
# 2025-03-17 00:00:00+00:00    46.154043
# 2025-03-18 00:00:00+00:00    45.088826
# 2025-03-19 00:00:00+00:00    48.484367
# 2025-03-20 00:00:00+00:00    47.121329
# Freq: D, Name: Close, Length: 2773, dtype: float64

# %%
entries, exits = rsi.rsi_crossed_below(30), rsi.rsi_crossed_above(70)
entries.value_counts(), exits.value_counts()
# Out:
# (Close
#  False    2735
#  True       38
#  Name: count, dtype: int64,
#  Close
#  False    2724
#  True       49
#  Name: count, dtype: int64)

# %%
def plot_rsi(rsi, entries, exits):
    fig = rsi.plot()
    entries.vbt.signals.plot_as_entries(rsi.rsi, fig=fig)
    exits.vbt.signals.plot_as_exits(rsi.rsi, fig=fig)
    fig.show()

plot_rsi(rsi, entries=entries, exits=exits)

# %%
entries, exits = entries.vbt.signals.clean(exits)
plot_rsi(rsi, entries=entries, exits=exits)

# %%
entries.vbt.signals.total(), exits.vbt.signals.total()
# Out:
# (np.int64(12), np.int64(12))

# %%
ranges = entries.vbt.signals.between_ranges(target=exits)
ranges.duration.values
# Out:
# array([273, 188,  45,  61,  18, 117, 254,  36,  34,  67, 209,  26])

# %%
ranges.duration.mean(), ranges.duration.mean(wrap_kwargs=dict(to_timedelta=True))
# Out:
# (np.float64(110.66666666666667), Timedelta('110 days 16:00:00'))

# %%
pf = vbt.Portfolio.from_signals(df.get('Close', 'ADAUSDT'), entries, exits, size=100, size_type="value", init_cash="auto")
pf.stats()
# Out:
# Start Index                   2017-08-17 00:00:00+00:00
# End Index                     2025-03-20 00:00:00+00:00
# Total Duration                       2773 days 00:00:00
# Start Value                                  192.635464
# Min Value                                     83.008442
# Max Value                                    342.810368
# End Value                                    342.810368
# Total Return [%]                              77.958077
# Benchmark Return [%]                         199.010717
# Position Coverage [%]                         47.890371
# Max Gross Exposure [%]                            100.0
# Max Drawdown [%]                              62.950076
# Max Drawdown Duration                1186 days 00:00:00
# Total Orders                                         24
# Total Fees Paid                                     0.0
# Total Trades                                         12
# Win Rate [%]                                  58.333333
# Best Trade [%]                                97.209103
# Worst Trade [%]                              -58.253269
# Avg Winning Trade [%]                         46.950256
# Avg Losing Trade [%]                         -35.695378
# Avg Winning Trade Duration             41 days 00:00:00
# Avg Losing Trade Duration             208 days 04:48:00
# Profit Factor                                  1.841425
# Expectancy                                    12.514575
# Sharpe Ratio                                   0.400523
# Calmar Ratio                                   0.125208
# Omega Ratio                                     1.10528
# Sortino Ratio                                   0.64537
# Name: Close, dtype: object

# %%
pf.plot(settings=dict(bm_returns=False))
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'mode': 'lines',
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e61109fd-5df8-47cf-bd53-bbf67d9cd8ac',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([   nan,    nan,    nan, ..., 0.7017, 0.7436, 0.7254]),
#               'yaxis': 'y'},
#              {'customdata': array([['0', '2018-06-22 00:00:00+00:00', '2018-06-22 00:00:00+00:00',
#                                     '2018-06-22 00:00:00+00:00', 722.3867658744492, 0.13843, 0.0,
#                                     'Market', 'None'],
#                                    ['2', '2019-07-11 00:00:00+00:00', '2019-07-11 00:00:00+00:00',
#                                     '2019-07-11 00:00:00+00:00', 1534.9194167306216, 0.06515, 0.0,
#                                     'Market', 'None'],
#                                    ['4', '2020-03-12 00:00:00+00:00', '2020-03-12 00:00:00+00:00',
#                                     '2020-03-12 00:00:00+00:00', 4293.688278231, 0.02329, 0.0, 'Market',
#                                     'None'],
#                                    ['6', '2020-09-21 00:00:00+00:00', '2020-09-21 00:00:00+00:00',
#                                     '2020-09-21 00:00:00+00:00', 1252.661906551422, 0.07983, 0.0,
#                                     'Market', 'None'],
#                                    ['8', '2021-07-20 00:00:00+00:00', '2021-07-20 00:00:00+00:00',
#                                     '2021-07-20 00:00:00+00:00', 94.8856627763545, 1.0539, 0.0, 'Market',
#                                     'None'],
#                                    ['10', '2021-11-26 00:00:00+00:00', '2021-11-26 00:00:00+00:00',
#                                     '2021-11-26 00:00:00+00:00', 65.23157208088715, 1.533, 0.0, 'Market',
#                                     'None'],
#                                    ['12', '2022-04-30 00:00:00+00:00', '2022-04-30 00:00:00+00:00',
#                                     '2022-04-30 00:00:00+00:00', 132.34515616728427, 0.7556, 0.0,
#                                     'Market', 'None'],
#                                    ['14', '2023-03-09 00:00:00+00:00', '2023-03-09 00:00:00+00:00',
#                                     '2023-03-09 00:00:00+00:00', 322.4766204450178, 0.3101, 0.0, 'Market',
#                                     'None'],
#                                    ['16', '2023-06-09 00:00:00+00:00', '2023-06-09 00:00:00+00:00',
#                                     '2023-06-09 00:00:00+00:00', 338.86818027787194, 0.2951, 0.0,
#                                     'Market', 'None'],
#                                    ['18', '2023-08-17 00:00:00+00:00', '2023-08-17 00:00:00+00:00',
#                                     '2023-08-17 00:00:00+00:00', 391.6960438699569, 0.2553, 0.0, 'Market',
#                                     'None'],
#                                    ['20', '2024-04-13 00:00:00+00:00', '2024-04-13 00:00:00+00:00',
#                                     '2024-04-13 00:00:00+00:00', 224.7696111485727, 0.4449, 0.0, 'Market',
#                                     'None'],
#                                    ['22', '2025-02-04 00:00:00+00:00', '2025-02-04 00:00:00+00:00',
#                                     '2025-02-04 00:00:00+00:00', 134.42667025137789, 0.7439, 0.0,
#                                     'Market', 'None']], dtype=object),
#               'hovertemplate': ('<br>Order Id: %{customdata[0]}' ... 'br>Stop Type: %{customdata[8]}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': '8fdc0f0c-f13d-40ad-90c7-9a3094fbd48a',
#               'x': array([datetime.datetime(2018, 6, 22, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2019, 7, 11, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 3, 12, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 9, 21, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 7, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 11, 26, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 4, 30, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 3, 9, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 6, 9, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 4, 13, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 2, 4, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([0.13843, 0.06515, 0.02329, 0.07983, 1.0539 , 1.533  , 0.7556 , 0.3101 ,
#                           0.2951 , 0.2553 , 0.4449 , 0.7439 ]),
#               'yaxis': 'y'},
#              {'customdata': array([['1', '2019-03-22 00:00:00+00:00', '2019-03-22 00:00:00+00:00',
#                                     '2019-03-22 00:00:00+00:00', 722.3867658744492, 0.05779, 0.0,
#                                     'Market', 'None'],
#                                    ['3', '2020-01-15 00:00:00+00:00', '2020-01-15 00:00:00+00:00',
#                                     '2020-01-15 00:00:00+00:00', 1534.9194167306216, 0.04275, 0.0,
#                                     'Market', 'None'],
#                                    ['5', '2020-04-26 00:00:00+00:00', '2020-04-26 00:00:00+00:00',
#                                     '2020-04-26 00:00:00+00:00', 4293.688278231, 0.04593, 0.0, 'Market',
#                                     'None'],
#                                    ['7', '2020-11-21 00:00:00+00:00', '2020-11-21 00:00:00+00:00',
#                                     '2020-11-21 00:00:00+00:00', 1252.661906551422, 0.13334, 0.0,
#                                     'Market', 'None'],
#                                    ['9', '2021-08-07 00:00:00+00:00', '2021-08-07 00:00:00+00:00',
#                                     '2021-08-07 00:00:00+00:00', 94.8856627763545, 1.4727, 0.0, 'Market',
#                                     'None'],
#                                    ['11', '2022-03-23 00:00:00+00:00', '2022-03-23 00:00:00+00:00',
#                                     '2022-03-23 00:00:00+00:00', 65.23157208088715, 1.108, 0.0, 'Market',
#                                     'None'],
#                                    ['13', '2023-01-09 00:00:00+00:00', '2023-01-09 00:00:00+00:00',
#                                     '2023-01-09 00:00:00+00:00', 132.34515616728427, 0.3168, 0.0,
#                                     'Market', 'None'],
#                                    ['15', '2023-04-14 00:00:00+00:00', '2023-04-14 00:00:00+00:00',
#                                     '2023-04-14 00:00:00+00:00', 322.4766204450178, 0.4381, 0.0, 'Market',
#                                     'None'],
#                                    ['17', '2023-07-13 00:00:00+00:00', '2023-07-13 00:00:00+00:00',
#                                     '2023-07-13 00:00:00+00:00', 338.86818027787194, 0.3567, 0.0,
#                                     'Market', 'None'],
#                                    ['19', '2023-10-23 00:00:00+00:00', '2023-10-23 00:00:00+00:00',
#                                     '2023-10-23 00:00:00+00:00', 391.6960438699569, 0.2807, 0.0, 'Market',
#                                     'None'],
#                                    ['21', '2024-11-08 00:00:00+00:00', '2024-11-08 00:00:00+00:00',
#                                     '2024-11-08 00:00:00+00:00', 224.7696111485727, 0.4447, 0.0, 'Market',
#                                     'None'],
#                                    ['23', '2025-03-02 00:00:00+00:00', '2025-03-02 00:00:00+00:00',
#                                     '2025-03-02 00:00:00+00:00', 134.42667025137789, 1.135, 0.0, 'Market',
#                                     'None']], dtype=object),
#               'hovertemplate': ('<br>Order Id: %{customdata[0]}' ... 'br>Stop Type: %{customdata[8]}'),
#               'legendgroup': '2',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': '4b2477ef-d422-4bed-8891-822880902ea2',
#               'x': array([datetime.datetime(2019, 3, 22, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 15, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 4, 26, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 11, 21, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 8, 7, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 3, 23, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 1, 9, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 4, 14, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 7, 13, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 10, 23, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 8, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 2, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([0.05779, 0.04275, 0.04593, 0.13334, 1.4727 , 1.108  , 0.3168 , 0.4381 ,
#                           0.3567 , 0.2807 , 0.4447 , 1.135  ]),
#               'yaxis': 'y'},
#              {'customdata': array([['2', '2', '2020-04-26 00:00:00+00:00', 97.20910261914983,
#                                     0.9720910261914983],
#                                    ['3', '3', '2020-11-21 00:00:00+00:00', 67.02993861956658,
#                                     0.6702993861956656],
#                                    ['4', '4', '2021-08-07 00:00:00+00:00', 39.73811557073725,
#                                     0.3973811557073725],
#                                    ['7', '7', '2023-04-14 00:00:00+00:00', 41.27700741696228,
#                                     0.41277007416962275],
#                                    ['8', '8', '2023-07-13 00:00:00+00:00', 20.87427990511692,
#                                     0.20874279905116921],
#                                    ['9', '9', '2023-10-23 00:00:00+00:00', 9.949079514296898,
#                                     0.09949079514296898],
#                                    ['11', '11', '2025-03-02 00:00:00+00:00', 52.574270735313874,
#                                     0.5257427073531387]], dtype=object),
#               'hovertemplate': ('<br>Exit Trade Id: %{customdat' ... 'br>Return: %{customdata[4]:,%}'),
#               'legendgroup': '3',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': array([0.9       , 0.85341003, 0.81127748, 0.81365319, 0.78215588, 0.76528978,
#                                            0.83109367]),
#                          'size': array([14.        , 11.82580148,  9.85961577,  9.9704822 ,  8.50060783,
#                                          7.71352325, 10.78437132]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': 'a3940409-d282-43c1-a464-174cb0feb45c',
#               'x': array([datetime.datetime(2020, 4, 26, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 11, 21, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 8, 7, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 4, 14, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 7, 13, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 10, 23, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 2, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([0.97209103, 0.67029939, 0.39738116, 0.41277007, 0.2087428 , 0.0994908 ,
#                           0.52574271]),
#               'yaxis': 'y2'},
#              {'customdata': array([['0', '0', '2019-03-22 00:00:00+00:00', -58.25326880011558,
#                                     -0.5825326880011558],
#                                    ['1', '1', '2020-01-15 00:00:00+00:00', -34.38219493476592,
#                                     -0.3438219493476592],
#                                    ['5', '5', '2022-03-23 00:00:00+00:00', -27.723418134377013,
#                                     -0.27723418134377015],
#                                    ['6', '6', '2023-01-09 00:00:00+00:00', -58.07305452620434,
#                                     -0.5807305452620434],
#                                    ['10', '10', '2024-11-08 00:00:00+00:00', -0.044953922229723275,
#                                     -0.00044953922229723275]], dtype=object),
#               'hovertemplate': ('<br>Exit Trade Id: %{customdat' ... 'br>Return: %{customdata[4]:,%}'),
#               'legendgroup': '4',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': array([0.83986079, 0.80300912, 0.79272944, 0.83958258, 0.75      ]),
#                          'size': array([11.19350357,  9.473759  ,  8.99404052, 11.18052038,  7.        ]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '09734872-561c-440c-9acf-06519c40f765',
#               'x': array([datetime.datetime(2019, 3, 22, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 15, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 3, 23, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 1, 9, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 8, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([-5.82532688e-01, -3.43821949e-01, -2.77234181e-01, -5.80730545e-01,
#                           -4.49539222e-04]),
#               'yaxis': 'y2'},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ca18368d-1e59-451c-834f-1f4bbc36bdc5',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(148,103,189,0.3000)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ee52697e-18d6-4d5c-81e3-b759ebec17fb',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.        , 1.        , ..., 1.77958077, 1.77958077,
#                           1.77958077]),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '17fbba5e-6dae-45b5-b8e2-01d1619ad822',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(220,57,18,0.3000)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f2252041-32aa-453c-b576-6377559ea54c',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1., 1., 1., ..., 1., 1., 1.]),
#               'yaxis': 'y3'},
#              {'legendgroup': '5',
#               'line': {'color': '#9467bd'},
#               'mode': 'lines',
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '04a4bd38-7bc6-4471-a79c-bad358f358fe',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.        , 1.        , ..., 1.77958077, 1.77958077,
#                           1.77958077]),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1293b6c5-32b4-45f1-b05c-b21a6d789d54',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False, 'title': {}},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False, 'title': {}},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative return'}}}
# })

# %% [markdown]
# ### Multiple Params Backtest

# %%
windows = list(range(8, 21))
window_types = ['simple', 'exp', 'wilder']
lower_ths = list(range(20, 31))
upper_ths = list(range(70, 81))

# %%
rsi = vbt.RSI.run(
    df.get('Open', 'ADAUSDT'),
    window=windows,
    wtype=window_types,
    param_product=True,
)
rsi.rsi
# Out:
# rsi_window                        8                                9   \
# rsi_wtype                     simple        exp     wilder     simple
# Open time
# 2017-08-17 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-18 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-19 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-20 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-21 00:00:00+00:00        NaN        NaN        NaN        NaN
# ...                              ...        ...        ...        ...
# 2025-03-16 00:00:00+00:00  37.664588  49.698413  47.701166  28.825245
# 2025-03-17 00:00:00+00:00  34.214668  38.141852  42.826189  32.889561
# 2025-03-18 00:00:00+00:00  49.169031  43.244494  44.766169  36.724190
# 2025-03-19 00:00:00+00:00  57.216981  38.168364  42.690265  46.209524
# 2025-03-20 00:00:00+00:00  54.875622  55.841616  49.752195  64.277275
#
# rsi_window                                              10             \
# rsi_wtype                        exp     wilder     simple        exp
# Open time
# 2017-08-17 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-18 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-19 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-20 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-21 00:00:00+00:00        NaN        NaN        NaN        NaN
# ...                              ...        ...        ...        ...
# 2025-03-16 00:00:00+00:00  48.803054  47.729026  24.443445  48.280402
# 2025-03-17 00:00:00+00:00  39.131522  43.512250  25.942721  39.985294
# 2025-03-18 00:00:00+00:00  43.351437  45.151597  35.354124  43.549985
# 2025-03-19 00:00:00+00:00  39.102218  43.375761  35.047674  39.916270
# 2025-03-20 00:00:00+00:00  54.036536  49.322200  53.613666  52.706340
#
# rsi_window                                   11  ...         17         18  \
# rsi_wtype                     wilder     simple  ...     wilder     simple
# Open time                                        ...
# 2017-08-17 00:00:00+00:00        NaN        NaN  ...        NaN        NaN
# 2017-08-18 00:00:00+00:00        NaN        NaN  ...        NaN        NaN
# 2017-08-19 00:00:00+00:00        NaN        NaN  ...        NaN        NaN
# 2017-08-20 00:00:00+00:00        NaN        NaN  ...        NaN        NaN
# 2017-08-21 00:00:00+00:00        NaN        NaN  ...        NaN        NaN
# ...                              ...        ...  ...        ...        ...
# 2025-03-16 00:00:00+00:00  47.769085  29.692404  ...  47.779802  52.286454
# 2025-03-17 00:00:00+00:00  44.036824  22.338677  ...  45.587364  52.054402
# 2025-03-18 00:00:00+00:00  45.460625  28.104727  ...  46.373589  52.572484
# 2025-03-19 00:00:00+00:00  43.904308  33.797715  ...  45.497694  52.442050
# 2025-03-20 00:00:00+00:00  49.044380  42.061856  ...  48.251692  52.955613
#
# rsi_window                                              19             \
# rsi_wtype                        exp     wilder     simple        exp
# Open time
# 2017-08-17 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-18 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-19 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-20 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-21 00:00:00+00:00        NaN        NaN        NaN        NaN
# ...                              ...        ...        ...        ...
# 2025-03-16 00:00:00+00:00  47.749218  47.759980  52.341281  47.769085
# 2025-03-17 00:00:00+00:00  43.791849  45.677488  50.757311  44.036824
# 2025-03-18 00:00:00+00:00  45.315091  46.421348  52.482974  45.460625
# 2025-03-19 00:00:00+00:00  43.656977  45.592425  51.988756  43.904308
# 2025-03-20 00:00:00+00:00  49.169583  48.190128  53.813851  49.044380
#
# rsi_window                                   20
# rsi_wtype                     wilder     simple        exp     wilder
# Open time
# 2017-08-17 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-18 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-19 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-20 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2017-08-21 00:00:00+00:00        NaN        NaN        NaN        NaN
# ...                              ...        ...        ...        ...
# 2025-03-16 00:00:00+00:00  47.740937  49.223288  47.786955  47.723886
# 2025-03-17 00:00:00+00:00  45.755928  50.812243  44.251889  45.826000
# 2025-03-18 00:00:00+00:00  46.462518  51.186605  45.589690  46.499481
# 2025-03-19 00:00:00+00:00  45.674999  51.901221  44.122214  45.748763
# 2025-03-20 00:00:00+00:00  48.135732  53.362004  48.939598  48.088286
#
# [2773 rows x 39 columns]

# %%
from itertools import product

lower_ths_prod, upper_ths_prod = zip(*product(lower_ths, upper_ths))
len(lower_ths_prod), len(upper_ths_prod)
# Out:
# (121, 121)

# %%
lower_ths_index = vbt.Param(lower_ths_prod, name='lower_th')
upper_ths_index = vbt.Param(upper_ths_prod, name='upper_ths')

entries = rsi.rsi_crossed_below(lower_ths_index)
exits = rsi.rsi_crossed_above(upper_ths_index)

entries.columns.shape, exits.columns.shape
# Out:
# ((4719,), (4719,))

# %%
pf = vbt.Portfolio.from_signals(
    df.get('Close', 'ADAUSDT'),
    entries=entries,
    exits=exits,
    size=100,
    size_type="value",
    init_cash="auto",
)
pf

# %%
pf.stats(['total_return', 'total_trades', 'win_rate', 'expectancy'], agg_func=None)
# Out:
#                                          Total Return [%]  Total Trades  \
# lower_th upper_ths rsi_window rsi_wtype
# 20       70        8          simple           -18.025853            47
#                               exp              -28.504551            40
#                               wilder            -7.181458            16
#                    9          simple            65.586850            44
#                               exp              -52.629968            35
# ...                                                   ...           ...
# 30       80        19         exp              -24.881817            11
#                               wilder           259.945626             3
#                    20         simple           115.132125            10
#                               exp               -1.963360            10
#                               wilder           687.125717             3
#
#                                          Win Rate [%]  Expectancy
# lower_th upper_ths rsi_window rsi_wtype
# 20       70        8          simple        54.347826   -0.855465
#                               exp           52.500000   -1.859529
#                               wilder        37.500000   -0.874305
#                    9          simple        65.909091    2.085653
#                               exp           51.428571   -3.858252
# ...                                               ...         ...
# 30       80        19         exp           50.000000   -3.855613
#                               wilder        33.333333  113.042681
#                    20         simple        44.444444   21.108935
#                               exp           55.555556    0.814338
#                               wilder        33.333333  298.810694
#
# [4719 rows x 4 columns]

# %%
pf.stats(metrics=['total_return'], split_columns=['lower_th', 'upper_th'], agg_func=None).groupby(
    ['lower_th', 'upper_ths']
).sum().vbt.heatmap()
# Out:
# FigureWidget({
#     'data': [{'colorscale': [[0.0, '#0d0887'], [0.1111111111111111, '#46039f'],
#                              [0.2222222222222222, '#7201a8'], [0.3333333333333333,
#                              '#9c179e'], [0.4444444444444444, '#bd3786'],
#                              [0.5555555555555556, '#d8576b'], [0.6666666666666666,
#                              '#ed7953'], [0.7777777777777778, '#fb9f3a'],
#                              [0.8888888888888888, '#fdca26'], [1.0, '#f0f921']],
#               'hoverongaps': False,
#               'type': 'heatmap',
#               'uid': 'e995bf75-5ad6-412e-954f-7b8d8a248f59',
#               'x': array(['Total Return [%]'], dtype=object),
#               'y': [(20, 70), (20, 71), (20, 72), (20, 73), (20, 74), (20, 75),
#                     (20, 76), (20, 77), (20, 78), (20, 79), (20, 80), (21, 70),
#                     (21, 71), (21, 72), (21, 73), (21, 74), (21, 75), (21, 76),
#                     (21, 77), (21, 78), (21, 79), (21, 80), (22, 70), (22, 71),
#                     (22, 72), (22, 73), (22, 74), (22, 75), (22, 76), (22, 77),
#                     (22, 78), (22, 79), (22, 80), (23, 70), (23, 71), (23, 72),
#                     (23, 73), (23, 74), (23, 75), (23, 76), (23, 77), (23, 78),
#                     (23, 79), (23, 80), (24, 70), (24, 71), (24, 72), (24, 73),
#                     (24, 74), (24, 75), (24, 76), (24, 77), (24, 78), (24, 79),
#                     (24, 80), (25, 70), (25, 71), (25, 72), (25, 73), (25, 74),
#                     (25, 75), (25, 76), (25, 77), (25, 78), (25, 79), (25, 80),
#                     (26, 70), (26, 71), (26, 72), (26, 73), (26, 74), (26, 75),
#                     (26, 76), (26, 77), (26, 78), (26, 79), (26, 80), (27, 70),
#                     (27, 71), (27, 72), (27, 73), (27, 74), (27, 75), (27, 76),
#                     (27, 77), (27, 78), (27, 79), (27, 80), (28, 70), (28, 71),
#                     (28, 72), (28, 73), (28, 74), (28, 75), (28, 76), (28, 77),
#                     (28, 78), (28, 79), (28, 80), (29, 70), (29, 71), (29, 72),
#                     (29, 73), (29, 74), (29, 75), (29, 76), (29, 77), (29, 78),
#                     (29, 79), (29, 80), (30, 70), (30, 71), (30, 72), (30, 73),
#                     (30, 74), (30, 75), (30, 76), (30, 77), (30, 78), (30, 79),
#                     (30, 80)],
#               'z': array([[  580.49718203],
#                           [  526.61057122],
#                           [  494.87123757],
#                           [  672.04944005],
#                           [  790.04100422],
#                           [  853.58095977],
#                           [ 1082.77085808],
#                           [ 1153.56041299],
#                           [ 1197.12716646],
#                           [ 1293.32309853],
#                           [ 1800.47239786],
#                           [  271.62670698],
#                           [  280.89130885],
#                           [  249.41572933],
#                           [  417.4156729 ],
#                           [  548.75625442],
#                           [  616.77478391],
#                           [  771.66577098],
#                           [  880.48525311],
#                           [  987.90876339],
#                           [ 1362.76123051],
#                           [ 1976.46233382],
#                           [  252.61637681],
#                           [  286.89118905],
#                           [  274.74577259],
#                           [  437.68718392],
#                           [  552.45307823],
#                           [  620.3229663 ],
#                           [  845.86961346],
#                           [ 1086.14222612],
#                           [ 1161.87532311],
#                           [ 1820.59633039],
#                           [ 2378.08836654],
#                           [  139.60827389],
#                           [  206.87736246],
#                           [  192.7149151 ],
#                           [  292.26481903],
#                           [  366.20611831],
#                           [  554.06086605],
#                           [  860.1449258 ],
#                           [ 1065.7462098 ],
#                           [ 1386.5056333 ],
#                           [ 2022.87966445],
#                           [ 2654.66364841],
#                           [  131.75215549],
#                           [  173.40694462],
#                           [  181.97974139],
#                           [  355.37837624],
#                           [  473.66212501],
#                           [  731.75029434],
#                           [  998.50995469],
#                           [ 1246.64226466],
#                           [ 1750.11714239],
#                           [ 2348.33194576],
#                           [ 3095.22680267],
#                           [   18.69355267],
#                           [   69.04627591],
#                           [   24.87262879],
#                           [  294.65432456],
#                           [  435.97517925],
#                           [  680.00037668],
#                           [  958.78073542],
#                           [ 1393.25771992],
#                           [ 1905.09232224],
#                           [ 2543.42111196],
#                           [ 3848.95506061],
#                           [ -107.36100649],
#                           [ -155.48355341],
#                           [ -129.60169749],
#                           [  118.57822842],
#                           [  198.44417399],
#                           [  452.73090981],
#                           [  797.69219012],
#                           [ 1410.90590758],
#                           [ 1898.14522778],
#                           [ 3157.61566751],
#                           [ 4411.70661478],
#                           [ -418.8189989 ],
#                           [ -454.81201883],
#                           [ -381.34857508],
#                           [ -236.83147307],
#                           [ -166.52253545],
#                           [  104.84443428],
#                           [  406.17775892],
#                           [ 1045.9065001 ],
#                           [ 1538.91438164],
#                           [ 2623.15944411],
#                           [ 3426.944444  ],
#                           [ -649.68908921],
#                           [ -667.50603974],
#                           [ -669.54335983],
#                           [ -528.82508146],
#                           [ -468.85522543],
#                           [ -178.0285211 ],
#                           [  132.30186811],
#                           [  757.82643099],
#                           [ 1192.135081  ],
#                           [ 2198.49701347],
#                           [ 2777.46622019],
#                           [ -970.73916655],
#                           [ -928.14410342],
#                           [ -929.281508  ],
#                           [ -769.8914358 ],
#                           [ -706.02923793],
#                           [ -408.28080057],
#                           [ -125.74444921],
#                           [  407.05731488],
#                           [  729.81685517],
#                           [ 1501.52224745],
#                           [ 2100.3676075 ],
#                           [-1173.52341876],
#                           [-1156.30929986],
#                           [-1180.60468042],
#                           [-1025.01730753],
#                           [ -935.15067924],
#                           [ -709.37248276],
#                           [ -519.70215638],
#                           [ -129.16221026],
#                           [  183.71824976],
#                           [  642.55279719],
#                           [  859.77695446]])}],
#     'layout': {'height': 489.99999999999994,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'template': '...',
#                'width': 365}
# })

# %%
# single combination of params
column_comb = (22, 80, 20, 'simple')
pf.plot_value(column=column_comb)
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f9241a26-6146-49aa-a31a-d7167fcd0642',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([154.18604651, 154.18604651, 154.18604651, ..., 154.18604651,
#                           154.18604651, 154.18604651])},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(148,103,189,0.3000)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1cf566f4-cb7a-4ed6-869c-d76344cf8bde',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([154.18604651, 154.18604651, 154.18604651, ..., 628.94624042,
#                           634.88781728, 632.30698914])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '78fe8293-88a3-42be-85bb-4fabb3cfca04',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([154.18604651, 154.18604651, 154.18604651, ..., 154.18604651,
#                           154.18604651, 154.18604651])},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(220,57,18,0.3000)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd10fc197-3135-485f-b26a-354d99b6d3fe',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([154.18604651, 154.18604651, 154.18604651, ..., 154.18604651,
#                           154.18604651, 154.18604651])},
#              {'line': {'color': '#9467bd'},
#               'mode': 'lines',
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5f2567ab-3fd7-4718-bd2c-0aa72d4b4bb6',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([154.18604651, 154.18604651, 154.18604651, ..., 628.94624042,
#                           634.88781728, 632.30698914])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'mode': 'lines',
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd8d2ac4e-7f45-4684-a879-a4fb0e78583b',
#               'x': array([datetime.datetime(2017, 8, 17, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2017, 8, 19, 0, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2025, 3, 18, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([154.18604651, 154.18604651, 154.18604651, ..., 154.18604651,
#                           154.18604651, 154.18604651])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': np.float64(154.18604651162792),
#                            'y1': np.float64(154.18604651162792),
#                            'yref': 'y'}],
#                'template': '...',
#                'width': 700}
# })

# %%
pf[column_comb].stats()
# Out:
# Start Index                   2017-08-17 00:00:00+00:00
# End Index                     2025-03-20 00:00:00+00:00
# Total Duration                       2773 days 00:00:00
# Start Value                                  154.186047
# Min Value                                     57.547684
# Max Value                                    690.389803
# End Value                                    632.306989
# Total Return [%]                             310.093522
# Benchmark Return [%]                         199.010717
# Position Coverage [%]                         43.635052
# Max Gross Exposure [%]                            100.0
# Max Drawdown [%]                              65.895881
# Max Drawdown Duration                 691 days 00:00:00
# Total Orders                                         15
# Total Fees Paid                                     0.0
# Total Trades                                          8
# Win Rate [%]                                  57.142857
# Best Trade [%]                               488.146324
# Worst Trade [%]                              -54.186047
# Avg Winning Trade [%]                        140.150506
# Avg Losing Trade [%]                         -28.448505
# Avg Winning Trade Duration            160 days 06:00:00
# Avg Losing Trade Duration             175 days 08:00:00
# Profit Factor                                  6.568617
# Expectancy                                    67.893787
# Sharpe Ratio                                   0.669157
# Calmar Ratio                                   0.309769
# Omega Ratio                                      1.1902
# Sortino Ratio                                  1.049862
# Name: (22, 80, 20, simple), dtype: object

# %%
# TODO: continue here with more exmaples
